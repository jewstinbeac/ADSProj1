# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
import warnings

warnings.filterwarnings("ignore")

# Start the spark context
sc = SparkContext.getOrCreate(conf=swan_spark_conf) 
print("Created Spark Context")

# create a spark session (which will run spark jobs)
spark = SparkSession.builder.getOrCreate()
print("Created Spark Session")

#  set good looking dataframes
spark.conf.set('spark.sql.repl.eagerEval.enabled', True)
print("Set Good Looking Dataframes")

# use Apache Arrow
spark.conf.set('spark.sql.execution.arrow.pyspark.enabled', True)
print("Using Apache Arrow")
# Out:
# Created Spark Context
# Created Spark Session
# Set Good Looking Dataframes
# Using Apache Arrow

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql import DataFrame as D

sdf = spark.read.parquet('./preprocessed_data/2018JunToAug.parquet')

# Filtering out obviously invalid rows and making sure the data is in
# the possible values listed in the data dictionary
sdf = sdf.filter(sdf.VendorID.isin([1,2])) \
.filter(sdf.passenger_count > 0) \
.filter(sdf.trip_distance > 0) \
.filter(sdf.PULocationID.isin(list(range(1,264)))) \
.filter(sdf.DOLocationID.isin(list(range(1,264)))) \
.filter(sdf.payment_type.isin([1,2])) \
.filter(((sdf.RateCodeID == 1) & (sdf.fare_amount >= 2.5)) | 
        ((sdf.fare_amount > 0) & (sdf.RateCodeID != 1))) \
.filter(sdf.extra >= 0) \
.filter(sdf.mta_tax >= 0) \
.filter(sdf.tip_amount >= 0) \
.filter(sdf.improvement_surcharge >= 0) \
.filter(sdf.total_amount == sdf.fare_amount + sdf.extra + sdf.mta_tax + 
        sdf.tip_amount + sdf.improvement_surcharge) \
.filter((sdf.PUDate >= F.lit("2018-06-01")) & (sdf.PUDate <= F.lit("2018-08-31"))) \
.filter((sdf.PUDate <= sdf.DODate)) \
.filter((sdf.RateCodeID.isin(list(range(1,7)))))

# Split the data based on whether the pickup date is on a weekday (Mon - Thur) or weekend (Fri - Sun)
sdf = sdf.withColumn("is_weekend", F.dayofweek('PUDate').isin([1,6,7])).orderBy("PUDate")

sdf_weekdays = sdf.filter(sdf.is_weekend == False)
sdf_weekends = sdf.filter(sdf.is_weekend == True)

# %%
#Check if there are any null values in any of the columns

names = sdf.schema.names
print("Count of Null values in each column")
for name in names:
    print(name + ': ' + str(sdf.where(sdf[name].isNull()).count()))
# Out:
# Count of Null values in each column
# VendorID: 0
# PUDate: 0
# DODate: 0
# passenger_count: 0
# trip_distance: 0
# RateCodeID: 0
# PULocationID: 0
# DOLocationID: 0
# payment_type: 0
# fare_amount: 0
# extra: 0
# mta_tax: 0
# tip_amount: 0
# tolls_amount: 0
# improvement_surcharge: 0
# total_amount: 0
# [Stage 51:=====================>                                    (3 + 5) / 8]
# is_weekend: 0
# [Stage 51:==================================================>       (7 + 1) / 8]

# %%
#Check whether there are any Nan values that need to be dealt with
for n, t in sdf.dtypes:
    if (t == "int") or (t == "double"):
        sdf.select(F.count(F.when(F.isnan(n), n)).alias(n)).show()
# Out:
# +--------+
# |VendorID|
# +--------+
# |       0|
# +--------+
# +---------------+
# |passenger_count|
# +---------------+
# |              0|
# +---------------+
# +-------------+
# |trip_distance|
# +-------------+
# |            0|
# +-------------+
# +----------+
# |RateCodeID|
# +----------+
# |         0|
# +----------+
# +------------+
# |PULocationID|
# +------------+
# |           0|
# +------------+
# +------------+
# |DOLocationID|
# +------------+
# |           0|
# +------------+
# +------------+
# |payment_type|
# +------------+
# |           0|
# +------------+
# +-----------+
# |fare_amount|
# +-----------+
# |          0|
# +-----------+
# +-----+
# |extra|
# +-----+
# |    0|
# +-----+
# +-------+
# |mta_tax|
# +-------+
# |      0|
# +-------+
# +----------+
# |tip_amount|
# +----------+
# |         0|
# +----------+
# +------------+
# |tolls_amount|
# +------------+
# |           0|
# +------------+
# +---------------------+
# |improvement_surcharge|
# +---------------------+
# |                    0|
# +---------------------+
# [Stage 79:==================================================>       (7 + 1) / 8]
# +------------+
# |total_amount|
# +------------+
# |           0|
# +------------+

# %%
def saveToParquet(sdf, fpath):
    if path.exists(fpath):
        rmtree(fpath)
    sdf.write.format('parquet').save(fpath)
    
saveToParquet(sdf_weekdays, './preprocessed_data/weekdaysBasicFilter.parquet')
saveToParquet(sdf_weekdays, './preprocessed_data/weekendsBasicFilter.parquet')
# Out:
# 21/08/09 11:01:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:21 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:01:23 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:23 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:23 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:01:24 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:24 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:25 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:25 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:01:25 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:26 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:26 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:01:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:30 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:47 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:47 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:01:48 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:48 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:48 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:49 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:49 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:01:49 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:49 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:01:49 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:50 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:50 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:01:50 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:51 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:01:51 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:51 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:51 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:01:51 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:52 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:01:52 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers

# %%
sdfWeekday = spark.read.parquet('./preprocessed_data/weekdaysBasicFilter.parquet')
sdfWeekend = spark.read.parquet('./preprocessed_data/weekendsBasicFilter.parquet')

# %%
from matplotlib import *
from matplotlib import patches

colours = {1:'r', 2:'y', 3:'b', 4:'m', 5:'g', 6:'k'}
rPatch = patches.Patch(color='r', label='RateCode1')
yPatch = patches.Patch(color='y', label='RateCode2')
bPatch = patches.Patch(color='b', label='RateCode3')
mPatch = patches.Patch(color='m', label='RateCode4')
gPatch = patches.Patch(color='g', label='RateCode5')
kPatch = patches.Patch(color='k', label='RateCode6')
legend_patches = [rPatch, yPatch, bPatch, mPatch, gPatch, kPatch]


dfDayBigTots = sdfWeekday.filter(sdfWeekday.total_amount > 100).toPandas()
dfEndBigTots = sdfWeekend.filter(sdfWeekend.total_amount > 100).toPandas()

dfDayBigFares = sdfWeekday.filter(sdfWeekday.fare_amount > 100).toPandas()
dfEndBigFares = sdfWeekend.filter(sdfWeekend.fare_amount > 100).toPandas()

def plotXvsY(df, xaxis, yaxis, category):    
    plot = df.plot.scatter(x = xaxis, y = yaxis, 
                           c = df["RateCodeID"].map(colours))
    plot.legend(handles = legend_patches, bbox_to_anchor=(1.05, 1), 
                loc='upper left')
    plot.set(title = xaxis + " VS "+yaxis+" for " + category",
         xlabel = xaxis,
         ylabel = yaxis)
    return plot
    
plot = plotXvsY(dfDayBigTots, "trip_distance", 
                "total_amount", "Weekday Totals >$100")
figure = plot.get_figure()
figure.savefig('./plots/WeekdaysBigTots.jpg', bbox_inches='tight')

plot = plotXvsY(dfDayBigFares, "trip_distance", 
                "fare_amount", "Weekday Fares >$100")
figure = plot.get_figure()
figure.savefig('./plots/WeekdaysBigFares.jpg', bbox_inches='tight')

plot = plotXvsY(dfEndBigTots, "trip_distance", 
                "total_amount", "Weekend Totals >$100")
figure = plot.get_figure()
figure.savefig('./plots/WeekendsBigTots.jpg', bbox_inches='tight')

plot = plotXvsY(dfEndBigFares, "trip_distance", 
                "fare_amount", "Weekend Fares >$100")
figure = plot.get_figure()
figure.savefig('./plots/WeekendsBigFares.jpg', bbox_inches='tight')

# %%
dfDayMedTots = sdfWeekday.filter((sdfWeekday.total_amount > 50) & 
                                 (sdfWeekday.total_amount <= 100)).toPandas()
dfEndMedTots = sdfWeekend.filter((sdfWeekend.total_amount > 50) & 
                                 (sdfWeekend.total_amount <= 100)).toPandas()

dfDayMedFares = sdfWeekday.filter((sdfWeekday.fare_amount > 50) & 
                                  (sdfWeekday.fare_amount <= 100)).toPandas()
dfEndMedFares = sdfWeekend.filter((sdfWeekend.fare_amount > 50) & 
                                  (sdfWeekend.fare_amount <= 100)).toPandas()

plot = plotXvsY(dfDayBigTots, "trip_distance", "total_amount", 
                "Weekday Totals \$50 to \$100")
figure = plot.get_figure()
figure.savefig('./plots/WeekdaysMedTots.jpg', bbox_inches='tight')

plot = plotXvsY(dfDayBigFares, "trip_distance", "fare_amount", 
                "Weekday Fares \$50 to \$100")
figure = plot.get_figure()
figure.savefig('./plots/WeekdaysMedFares.jpg', bbox_inches='tight')

plot = plotXvsY(dfEndBigTots, "trip_distance", "total_amount", 
                "Weekend Total \$50 to \$100")
figure = plot.get_figure()
figure.savefig('./plots/WeekendsMedTots.jpg', bbox_inches='tight')

plot = plotXvsY(dfEndBigFares, "trip_distance", "fare_amount", 
                "Weekend Fares \$50 to \$100")
figure = plot.get_figure()
figure.savefig('./plots/WeekendsMedFares.jpg', bbox_inches='tight')

# %%
dfDaySmallTots = sdfWeekday.filter(sdfWeekday.total_amount < 3).toPandas()
dfEndSmallTots = sdfWeekend.filter(sdfWeekend.total_amount < 3).toPandas()

dfDaySmallFares = sdfWeekday.filter(sdfWeekday.fare_amount < 3).toPandas()
dfEndSmallFares = sdfWeekend.filter(sdfWeekend.fare_amount < 3).toPandas()

plot = plotXvsY(dfDaySmallTots, "trip_distance", "total_amount", 
                "Weekend Fares <$3")
figure = plot.get_figure()
figure.savefig('./plots/WeekdaysSmallTots.jpg', bbox_inches='tight')

plot = plotXvsY(dfDaySmallFares, "trip_distance", "fare_amount", 
                "Weekend Fares <$3")
figure = plot.get_figure()
figure.savefig('./plots/WeekdaysSmallFares.jpg', bbox_inches='tight')

plot = plotXvsY(dfEndSmallTots, "trip_distance", "total_amount", 
                "Weekend Fares <$3")
figure = plot.get_figure()
figure.savefig('./plots/WeekendsSmallTots.jpg', bbox_inches='tight')

plot = plotXvsY(dfEndSmallFares, "trip_distance", "fare_amount", 
                "Weekend Fares <$3")
figure = plot.get_figure()
figure.savefig('./plots/WeekendsSmallFares.jpg', bbox_inches='tight')

# %%
# Removing some more rows now that we can see some rows that are obviously sketchy
# Trips that are low distance but incurred a suspiciouly high standard fare
# Trips that had fares below $2.50
# Trips that had fares above $800

sdf = sdf.filter(((sdf.trip_distance < 5) & (sdf.fare_amount > 60) & 
                  (sdf.RateCodeID == 1)) == False) \
.filter(((sdf.fare_amount < 2.5) & (sdf.trip_distance > 5)) == False) \
.filter(((sdf.fare_amount < 2.5) & (sdf.RateCodeID.isin([4,5]))) == False) \
.filter((sdf.fare_amount < 800))

sdfWeekdays2 = sdf.filter(sdf.is_weekend == False)
sdfWeekends2 = sdf.filter(sdf.is_weekend == True)

# %%
saveToParquet(sdf, './preprocessed_data/2018JunToAugRemovedInvalids.parquet')
# Out:
# 21/08/09 11:06:01 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:01 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:06:01 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:02 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:02 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:06:03 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:03 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:03 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:04 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:04 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:04 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:04 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:06:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:05 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:06 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:06 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:06:06 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:06 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:06:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:07 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:06:08 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:09 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:09 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:06:10 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:11 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:11 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:12 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:06:12 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:06:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:13 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:14 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:14 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:15 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:06:15 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers

# %%
saveToParquet(sdfWeekdays2, './preprocessed_data/weekdayRemovedInvalids.parquet')
saveToParquet(sdfWeekdays2, './preprocessed_data/weekendsRemovedInvalids.parquet')
# Out:
# 21/08/09 11:07:25 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:25 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:07:26 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:07:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:07:27 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:07:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:28 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:29 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:30 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:30 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:30 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:31 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:31 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:31 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:32 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:32 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:32 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:07:32 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:07:32 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:31 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:31 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:08:32 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:33 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:33 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:08:33 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:33 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:34 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:34 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:08:34 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:34 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:35 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:08:35 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:35 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:35 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:08:35 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:35 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:36 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 84.47% for 8 writers
# 21/08/09 11:08:36 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:36 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers
# 21/08/09 11:08:37 WARN MemoryManager: Total allocation exceeds 95.00% (906,992,014 bytes) of heap memory
# Scaling row group sizes to 96.54% for 7 writers

# %%
sdfWeekday2 = spark.read.parquet('./preprocessed_data/weekdayRemovedInvalids.parquet')
sdfWeekend2 = spark.read.parquet('./preprocessed_data/weekendsRemovedInvalids.parquet')

# %%
dfDayBigTots2 = sdfWeekday2.filter(sdfWeekday2.total_amount > 100).toPandas()
dfEndBigTots2 = sdfWeekend2.filter(sdfWeekend2.total_amount > 100).toPandas()

dfDayBigFares2 = sdfWeekday2.filter(sdfWeekday2.fare_amount > 100).toPandas()
dfEndBigFares2 = sdfWeekend2.filter(sdfWeekend2.fare_amount > 100).toPandas()

plot = plotXvsY(dfDayBigTots2, "trip_distance", "total_amount", 
                "Weekday Totals >$100")
figure = plot.get_figure()
figure.savefig('./plots/WeekdaysBigTots2.jpg', bbox_inches='tight')

plot = plotXvsY(dfDayBigFares2, "trip_distance", "fare_amount", 
                "Weekday Fares >$100")
figure = plot.get_figure()
figure.savefig('./plots/WeekdaysBigFares2.jpg', bbox_inches='tight')

plot = plotXvsY(dfEndBigTots2, "trip_distance", "total_amount", 
                "Weekend Totals >$100")
figure = plot.get_figure()
figure.savefig('./plots/WeekendsBigTots2.jpg', bbox_inches='tight')

plot = plotXvsY(dfEndBigFares2, "trip_distance", "fare_amount", 
                "Weekend Fares >$100")
figure = plot.get_figure()
figure.savefig('./plots/WeekendsBigFares2.jpg', bbox_inches='tight')

# %%
dfDaySmallTots2 = sdfWeekday2.filter(sdfWeekday2.total_amount < 3).toPandas()
dfEndSmallTots2 = sdfWeekend2.filter(sdfWeekend2.total_amount < 3).toPandas()

dfDaySmallFares2 = sdfWeekday2.filter(sdfWeekday2.fare_amount < 3).toPandas()
dfEndSmallFares2 = sdfWeekend2.filter(sdfWeekend2.fare_amount < 3).toPandas()

plot = plotXvsY(dfDaySmallTots2, "trip_distance", "total_amount", 
                "Weekend Fares <$3")
figure = plot.get_figure()
figure.savefig('./plots/WeekdaysSmallTots2.jpg', bbox_inches='tight')

plot = plotXvsY(dfDaySmallFares2, "trip_distance", "fare_amount", 
                "Weekend Fares <$3")
figure = plot.get_figure()
figure.savefig('./plots/WeekdaysSmallFares2.jpg', bbox_inches='tight')

plot = plotXvsY(dfEndSmallTots2, "trip_distance", "total_amount", 
                "Weekend Fares <$3")
figure = plot.get_figure()
figure.savefig('./plots/WeekendsSmallTots2.jpg', bbox_inches='tight')

plot = plotXvsY(dfEndSmallFares2, "trip_distance", "fare_amount", 
                "Weekend Fares <$3")
figure = plot.get_figure()
figure.savefig('./plots/WeekendsSmallFares2.jpg', bbox_inches='tight')
